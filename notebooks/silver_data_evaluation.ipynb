# %%
import pandas as pd
df = pd.read_csv("MASTER_CAR_DATASET.csv") # Or whatever your file is called
silver = df[df['data_source'] == 'silver_predicted']

print("Silver Data Distribution:")
print(silver['inspection_score'].value_counts(bins=[0, 7.5, 9.0, 10.0], normalize=True) * 100)
# Out:
# Silver Data Distribution:
# (9.0, 10.0]      61.932162
# (7.5, 9.0]       33.615990
# (-0.001, 7.5]     4.451847
# Name: proportion, dtype: float64
